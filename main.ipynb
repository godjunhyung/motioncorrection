# %%
from load_data.dataset import CustomDataset
import torch
import matplotlib.pyplot as plt

# %%
if __name__ == "__main__":
    csv_path = "/Users/sin-yulim/Documents/MRmotion/motioncorrection/iqm_csv/fr-iqm.csv"
    iqm_label = "VIF"
    train_dataset = CustomDataset(csv_path, iqm_label)
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=3, shuffle=True)
    # for x, y, sequence in train_loader:
    #     print(x.shape, y, sequence) 
    x, y1, y2 = next(iter(train_loader))
    print(x.shape, y1, y2)
    print(y1.shape)
# Out:
# torch.Size([1200, 1, 396, 396])
# Read 1200 records
# torch.Size([3, 1, 396, 396]) tensor([ 64.,  17., 100.]) ('t1post', 't2', 'flair')
# torch.Size([3])

# %%
for i in range(3):
    plt.imshow(x[i][0], cmap='gray', origin='lower'), plt.axis('off')
    plt.show()
